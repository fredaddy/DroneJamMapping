# %%
from stable_baselines3 import PPO
from DroneJammingEnv import DroneJammingEnv
import numpy as np

# Create the environment
env = DroneJammingEnv()

# Initialize the PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Training parameters
total_timesteps = 100
log_interval = 5

# Lists to store progress
mean_rewards = []
ep_lengths = []

# Train the agent
for t in range(1, total_timesteps + 1):
    # Perform one step of the environment
    obs = env.reset()
    done = False
    ep_reward = 0
    ep_length = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        ep_reward += reward
        ep_length += 1

    # Store episode metrics
    mean_rewards.append(ep_reward)
    ep_lengths.append(ep_length)

    # Train the agent on a batch of experiences
    model.learn(total_timesteps=log_interval, reset_num_timesteps=False)

    # Log progress
    if t % log_interval == 0:
        mean_reward = np.mean(mean_rewards[-log_interval:])
        mean_ep_length = np.mean(ep_lengths[-log_interval:])
        print(f"Step: {t}, Mean Reward: {mean_reward}, Mean Episode Length: {mean_ep_length}")

# Save the final model
model.save("ppo_drone_search")

# Plot progress
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(mean_rewards)
plt.xlabel("Steps")
plt.ylabel("Mean Reward")
plt.title("Mean Reward vs. Steps")

plt.subplot(1, 2, 2)
plt.plot(ep_lengths)
plt.xlabel("Steps")
plt.ylabel("Episode Length")
plt.title("Episode Length vs. Steps")

plt.tight_layout()
plt.show()

# Close the environment
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\Samuel Chian\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -1.37e+04 |
# | time/              |           |
# |    fps             | 325       |
# |    iterations      | 1         |
# |    time_elapsed    | 6         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 810       |
# |    ep_rew_mean     | -1.07e+04 |
# | time/              |           |
# |    fps             | 415       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 4096      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 762       |
# |    ep_rew_mean     | -9.88e+03 |
# | time/              |           |
# |    fps             | 235       |
# |    iterations      | 1         |
# |    time_elapsed    | 8         |
# |    total_timesteps | 6144      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 741       |
# |    ep_rew_mean     | -9.66e+03 |
# | time/              |           |
# |    fps             | 245       |
# |    iterations      | 1         |
# |    time_elapsed    | 8         |
# |    total_timesteps | 8192      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 728       |
# |    ep_rew_mean     | -9.59e+03 |
# | time/              |           |
# |    fps             | 381       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 10240     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 720       |
# |    ep_rew_mean     | -9.39e+03 |
# | time/              |           |
# |    fps             | 460       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 12288     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 715       |
# |    ep_rew_mean     | -9.23e+03 |
# | time/              |           |
# |    fps             | 277       |
# |    iterations      | 1         |
# |    time_elapsed    | 7         |
# |    total_timesteps | 14336     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 710       |
# |    ep_rew_mean     | -9.16e+03 |
# | time/              |           |
# |    fps             | 314       |
# |    iterations      | 1         |
# |    time_elapsed    | 6         |
# |    total_timesteps | 16384     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 707       |
# |    ep_rew_mean     | -9.14e+03 |
# | time/              |           |
# |    fps             | 388       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 18432     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 705       |
# |    ep_rew_mean     | -9.05e+03 |
# | time/              |           |
# |    fps             | 331       |
# |    iterations      | 1         |
# |    time_elapsed    | 6         |
# |    total_timesteps | 20480     |
# ----------------------------------
# Step: 10, Mean Reward: -12732.010319079433, Mean Episode Length: 1001.0
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 703       |
# |    ep_rew_mean     | -8.99e+03 |
# | time/              |           |
# |    fps             | 451       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 22528     |
# ----------------------------------
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 22
#      19 # Train the agent
#      20 for t in range(1, total_timesteps + 1):
#      21     # Perform one step of the environment
# ---> 22     obs = env.reset()
#      23     done = False
#      24     ep_reward = 0
#
# File ~\DroneJamMapping\DroneJammingEnv.py:80, in DroneJammingEnv.reset(self)
#      79 def reset(self):
# ---> 80     p.resetSimulation()
#      81     p.setGravity(0, 0, -9.8)
#      82     p.setTimeStep(self.time_step)
#
# error: Not connected to physics server.
